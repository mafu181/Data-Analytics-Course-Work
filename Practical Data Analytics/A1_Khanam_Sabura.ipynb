# %%
import pandas as pd
df_rat=pd.read_csv('employee_rating.csv')
df_rat
# Out:
#       EmployeeNumber              Department EnvironmentSatisfaction  \
# 0                  1                   Sales                  Medium
# 1                  2  Research & Development                    High
# 2                  4  Research & Development               Very High
# 3                  5  Research & Development               Very High
# 4                  7  Research & Development                     Low
# ...              ...                     ...                     ...
# 1465            2061  Research & Development                    High
# 1466            2062  Research & Development               Very High
# 1467            2064  Research & Development                  Medium
# 1468            2065                   Sales               Very High
# 1469            2068  Research & Development                  Medium
#
#                         JobRole PerformanceRating  YearsAtCompany  \
# 0               Sales Executive         Excellent               6
# ...

# %%
import pandas as pd
df_gen=pd.read_csv('employee_general.csv', sep="|")
df_gen
# Out:
#       EmployeeNumber      Education EducationField MaritalStatus
# 0                  1        College  Life Sciences        Single
# 1                  2  Below College  Life Sciences       Married
# 2                  4        College          Other        Single
# 3                  5         Master  Life Sciences       Married
# 4                  7  Below College        Medical       Married
# ...              ...            ...            ...           ...
# 1465            2061        College        Medical       Married
# 1466            2062  Below College        Medical       Married
# 1467            2064       Bachelor  Life Sciences       Married
# 1468            2065       Bachelor        Medical       Married
# 1469            2068       Bachelor        Medical       Married
#
# [1470 rows x 4 columns]

# %%
df_rat['NewMonthlyIncome']=df_rat['MonthlyIncome']
df_rat
# Out:
#       EmployeeNumber              Department EnvironmentSatisfaction  \
# 0                  1                   Sales                  Medium
# 1                  2  Research & Development                    High
# 2                  4  Research & Development               Very High
# 3                  5  Research & Development               Very High
# 4                  7  Research & Development                     Low
# ...              ...                     ...                     ...
# 1465            2061  Research & Development                    High
# 1466            2062  Research & Development               Very High
# 1467            2064  Research & Development                  Medium
# 1468            2065                   Sales               Very High
# 1469            2068  Research & Development                  Medium
#
#                         JobRole PerformanceRating  YearsAtCompany  \
# 0               Sales Executive         Excellent               6
# ...

# %%
NewValue=(df_rat['YearsAtCompany']>6) | (df_rat['YearsInCurrentRole']>3)
df_rat.loc[NewValue, 'NewMonthlyIncome'] = df_rat.loc[NewValue, 'MonthlyIncome']*1.1
df_rat
# Out:
#       EmployeeNumber              Department EnvironmentSatisfaction  \
# 0                  1                   Sales                  Medium
# 1                  2  Research & Development                    High
# 2                  4  Research & Development               Very High
# 3                  5  Research & Development               Very High
# 4                  7  Research & Development                     Low
# ...              ...                     ...                     ...
# 1465            2061  Research & Development                    High
# 1466            2062  Research & Development               Very High
# 1467            2064  Research & Development                  Medium
# 1468            2065                   Sales               Very High
# 1469            2068  Research & Development                  Medium
#
#                         JobRole PerformanceRating  YearsAtCompany  \
# 0               Sales Executive         Excellent               6
# ...

# %%
df_rat.drop(['MonthlyIncome'], axis = 1)
#df_rat['Department', 'EnvironmentSatisfaction', 'JobRole', 'PerformanceRating'].unique()
# Out:
#       EmployeeNumber              Department EnvironmentSatisfaction  \
# 0                  1                   Sales                  Medium
# 1                  2  Research & Development                    High
# 2                  4  Research & Development               Very High
# 3                  5  Research & Development               Very High
# 4                  7  Research & Development                     Low
# ...              ...                     ...                     ...
# 1465            2061  Research & Development                    High
# 1466            2062  Research & Development               Very High
# 1467            2064  Research & Development                  Medium
# 1468            2065                   Sales               Very High
# 1469            2068  Research & Development                  Medium
#
#                         JobRole PerformanceRating  YearsAtCompany  \
# 0               Sales Executive         Excellent               6
# ...

# %%
df_rat['EnvironmentSatisfaction'].unique()
# Out:
# array(['Medium', 'High', 'Very High', 'Low'], dtype=object)

# %%
df_rat['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df_rat['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
df_rat['PerformanceRating'].unique()
# Out:
# array(['Excellent', 'Outstanding'], dtype=object)

# %%
df_gen.loc[:, df_gen.columns!='EmployeeNumber']
# Out:
#           Education EducationField MaritalStatus
# 0           College  Life Sciences        Single
# 1     Below College  Life Sciences       Married
# 2           College          Other        Single
# 3            Master  Life Sciences       Married
# 4     Below College        Medical       Married
# ...             ...            ...           ...
# 1465        College        Medical       Married
# 1466  Below College        Medical       Married
# 1467       Bachelor  Life Sciences       Married
# 1468       Bachelor        Medical       Married
# 1469       Bachelor        Medical       Married
#
# [1470 rows x 3 columns]

# %%
df_rat.loc[10:]
# Out:
#       EmployeeNumber              Department EnvironmentSatisfaction  \
# 10                14  Research & Development                     Low
# 11                15  Research & Development               Very High
# 12                16  Research & Development                     Low
# 13                18  Research & Development                  Medium
# 14                19  Research & Development                    High
# ...              ...                     ...                     ...
# 1465            2061  Research & Development                    High
# 1466            2062  Research & Development               Very High
# 1467            2064  Research & Development                  Medium
# 1468            2065                   Sales               Very High
# 1469            2068  Research & Development                  Medium
#
#                         JobRole PerformanceRating  YearsAtCompany  \
# 10        Laboratory Technician         Excellent               5
# ...

# %%
EnvironmentSatisfaction_map = {
    'Low':1, 
    'Medium':2, 
    'High':3,
    'Very High':4
}
df_rat['EnvironmentSatisfaction_score'] = df_rat['EnvironmentSatisfaction'].map(EnvironmentSatisfaction_map)
df_rat
# Out:
#       EmployeeNumber              Department EnvironmentSatisfaction  \
# 0                  1                   Sales                  Medium
# 1                  2  Research & Development                    High
# 2                  4  Research & Development               Very High
# 3                  5  Research & Development               Very High
# 4                  7  Research & Development                     Low
# ...              ...                     ...                     ...
# 1465            2061  Research & Development                    High
# 1466            2062  Research & Development               Very High
# 1467            2064  Research & Development                  Medium
# 1468            2065                   Sales               Very High
# 1469            2068  Research & Development                  Medium
#
#                         JobRole PerformanceRating  YearsAtCompany  \
# 0               Sales Executive         Excellent               6
# ...

# %%
PerformanceRating_map = {
    'Excellent':3, 
    'Outstanding':5 
}
df_rat['PerformanceRating_score'] = df_rat['PerformanceRating'].map(PerformanceRating_map)
df_rat
# Out:
#       EmployeeNumber              Department EnvironmentSatisfaction  \
# 0                  1                   Sales                  Medium
# 1                  2  Research & Development                    High
# 2                  4  Research & Development               Very High
# 3                  5  Research & Development               Very High
# 4                  7  Research & Development                     Low
# ...              ...                     ...                     ...
# 1465            2061  Research & Development                    High
# 1466            2062  Research & Development               Very High
# 1467            2064  Research & Development                  Medium
# 1468            2065                   Sales               Very High
# 1469            2068  Research & Development                  Medium
#
#                         JobRole PerformanceRating  YearsAtCompany  \
# 0               Sales Executive         Excellent               6
# ...

# %%
df_all=df_gen.merge(df_rat, on='EmployeeNumber', how = 'left')
df_all
# Out:
#       EmployeeNumber      Education EducationField MaritalStatus  \
# 0                  1        College  Life Sciences        Single
# 1                  2  Below College  Life Sciences       Married
# 2                  4        College          Other        Single
# 3                  5         Master  Life Sciences       Married
# 4                  7  Below College        Medical       Married
# ...              ...            ...            ...           ...
# 1465            2061        College        Medical       Married
# 1466            2062  Below College        Medical       Married
# 1467            2064       Bachelor  Life Sciences       Married
# 1468            2065       Bachelor        Medical       Married
# 1469            2068       Bachelor        Medical       Married
#
#                   Department EnvironmentSatisfaction  \
# 0                      Sales                  Medium
# 1     Research & Development                    High
# ...

# %%
df_all.head()
# Out:
#    EmployeeNumber      Education EducationField MaritalStatus  \
# 0               1        College  Life Sciences        Single
# 1               2  Below College  Life Sciences       Married
# 2               4        College          Other        Single
# 3               5         Master  Life Sciences       Married
# 4               7  Below College        Medical       Married
#
#                Department EnvironmentSatisfaction                JobRole  \
# 0                   Sales                  Medium        Sales Executive
# 1  Research & Development                    High     Research Scientist
# 2  Research & Development               Very High  Laboratory Technician
# 3  Research & Development               Very High     Research Scientist
# 4  Research & Development                     Low  Laboratory Technician
#
#   PerformanceRating  YearsAtCompany  YearsInCurrentRole  MonthlyIncome  \
# 0         Excellent               6                   4           5993
# ...

# %%
df_all.tail()
# Out:
#       EmployeeNumber      Education EducationField MaritalStatus  \
# 1465            2061        College        Medical       Married
# 1466            2062  Below College        Medical       Married
# 1467            2064       Bachelor  Life Sciences       Married
# 1468            2065       Bachelor        Medical       Married
# 1469            2068       Bachelor        Medical       Married
#
#                   Department EnvironmentSatisfaction  \
# 1465  Research & Development                    High
# 1466  Research & Development               Very High
# 1467  Research & Development                  Medium
# 1468                   Sales               Very High
# 1469  Research & Development                  Medium
#
#                         JobRole PerformanceRating  YearsAtCompany  \
# 1465      Laboratory Technician         Excellent               5
# 1466  Healthcare Representative         Excellent               7
# ...
