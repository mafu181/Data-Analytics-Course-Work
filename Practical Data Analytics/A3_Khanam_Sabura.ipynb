# %% [markdown]
# # Question 1:

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

df = pd.read_csv('boston_v2.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO  LSTAT  MEDV
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %%
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# # Question 2:

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
import matplotlib.pyplot as plt

df.hist(bins=10, figsize=(15,15))
plt.show()

# %% [markdown]
# # Question 3:

# %%
x = df.drop(['MEDV'], axis=1)
y = df['MEDV']

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import ShuffleSplit
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.25, random_state=0)
train_x.shape, test_x.shape, train_y.shape, test_y.shape
# Out:
# ((379, 12), (127, 12), (379,), (127,))

# %%
train_x.head()
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 245   0.19133  22.0   5.86     0  0.431  5.605  70.2  7.9549    7  330
# 59    0.10328  25.0   5.13     0  0.453  5.927  47.2  6.9320    8  284
# 276   0.10469  40.0   6.41     1  0.447  7.267  49.0  4.7872    4  254
# 395   8.71675   0.0  18.10     0  0.693  6.471  98.8  1.7257   24  666
# 416  10.83420   0.0  18.10     0  0.679  6.782  90.8  1.8195   24  666
#
#      PTRATIO  LSTAT
# 245     19.1  18.46
# 59      19.7   9.22
# 276     17.6   6.05
# 395     20.2  17.12
# 416     20.2  25.79

# %%
train_y.head()
# Out:
# 245    18.5
# 59     19.6
# 276    33.2
# 395    13.1
# 416     7.5
# Name: MEDV, dtype: float64

# %%
test_x.head()
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 329   0.06724  0.0   3.24     0  0.460  6.333   17.2  5.2146    4  430
# 371   9.23230  0.0  18.10     0  0.631  6.216  100.0  1.1691   24  666
# 219   0.11425  0.0  13.89     1  0.550  6.373   92.4  3.3633    5  276
# 403  24.80170  0.0  18.10     0  0.693  5.349   96.0  1.7028   24  666
# 78    0.05646  0.0  12.83     0  0.437  6.232   53.7  5.0141    5  398
#
#      PTRATIO  LSTAT
# 329     16.9   7.34
# 371     20.2   9.53
# 219     16.4  10.50
# 403     20.2  19.77
# 78      18.7  12.34

# %%
test_y.head()
# Out:
# 329    22.6
# 371    50.0
# 219    23.0
# 403     8.3
# 78     21.2
# Name: MEDV, dtype: float64

# %% [markdown]
# # Question 4:

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  
y = np.array([2, 8, 18, 32, 50])  

pipeline = Pipeline([
    ("poly_features", PolynomialFeatures(degree=2, include_bias=False)),
    ("scaler", StandardScaler()),
    ("linear_regression", LinearRegression())
])

# %% [markdown]
# # Question 5:

# %%
pipeline.fit(train_x, train_y)
predictions = pipeline.predict(test_x)

mse = mean_squared_error(test_y, predictions)
print(f"Mean Squared Error on Test Data: {mse}")
# Out:
# Mean Squared Error on Test Data: 15.955604463867148

# %% [markdown]
# # Question 6:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso, Ridge, ElasticNet
 
lasso = Lasso()
ridge = Ridge()
elastic_net = ElasticNet()

param_grid_lasso = {'alpha': np.linspace(0.1, 2, 20)} 
param_grid_ridge = {'alpha': np.linspace(0.1, 2, 20)}  
param_grid_elastic_net = {
    'alpha': np.linspace(0.1, 2, 20),  
    'l1_ratio': np.linspace(0.1, 0.9, 9)  
}
grid_search_lasso = GridSearchCV(lasso, param_grid_lasso, cv=5, scoring='neg_mean_squared_error')
grid_search_ridge = GridSearchCV(ridge, param_grid_ridge, cv=5, scoring='neg_mean_squared_error')
grid_search_elastic_net = GridSearchCV(elastic_net, param_grid_elastic_net, cv=5, scoring='neg_mean_squared_error')

grid_search_lasso.fit(train_x, train_y)
grid_search_ridge.fit(train_x, train_y)
grid_search_elastic_net.fit(train_x, train_y)

best_lasso = grid_search_lasso.best_estimator_
best_ridge = grid_search_ridge.best_estimator_
best_elastic_net = grid_search_elastic_net.best_estimator_

lasso_predictions = best_lasso.predict(test_x)
ridge_predictions = best_ridge.predict(test_x)
elastic_net_predictions = best_elastic_net.predict(test_x)

lasso_mse = mean_squared_error(test_y, lasso_predictions)
ridge_mse = mean_squared_error(test_y, ridge_predictions)
elastic_net_mse = mean_squared_error(test_y, elastic_net_predictions)

# %% [markdown]
# # Question no 7:

# %%
print(f"Lasso MSE on Test Data: {lasso_mse}")
print(f"Ridge MSE on Test Data: {ridge_mse}")
print(f"Elastic Net MSE on Test Data: {elastic_net_mse}")
# Out:
# Lasso MSE on Test Data: 33.42796927220597
# Ridge MSE on Test Data: 30.604966800825697
# Elastic Net MSE on Test Data: 33.11984749910215

# %% [markdown]
# # Question no 8:

# %%
linear_reg = LinearRegression()
linear_reg.fit(train_x, train_y)
linear_reg_train_predictions = linear_reg.predict(train_x)
linear_reg_test_predictions = linear_reg.predict(test_x)

linear_reg_train_mse = mean_squared_error(train_y, linear_reg_train_predictions)
linear_reg_test_mse = mean_squared_error(test_y, linear_reg_test_predictions)

print("Linear Regression Model:")
print(f"Train MSE: {linear_reg_train_mse}")
print(f"Test MSE: {linear_reg_test_mse}")

lasso_train_predictions = best_lasso.predict(train_x)
lasso_test_predictions = best_lasso.predict(test_x)

lasso_train_mse = mean_squared_error(train_y, lasso_train_predictions)
lasso_test_mse = mean_squared_error(test_y, lasso_test_predictions)

print("\nLasso Regression Model:")
print(f"Train MSE: {lasso_train_mse}")
print(f"Test MSE: {lasso_test_mse}")

ridge_train_predictions = best_ridge.predict(train_x)
ridge_test_predictions = best_ridge.predict(test_x)

ridge_train_mse = mean_squared_error(train_y, ridge_train_predictions)
ridge_test_mse = mean_squared_error(test_y, ridge_test_predictions)

print("\nRidge Regression Model:")
print(f"Train MSE: {ridge_train_mse}")
print(f"Test MSE: {ridge_test_mse}")

elastic_net_train_predictions = best_elastic_net.predict(train_x)
elastic_net_test_predictions = best_elastic_net.predict(test_x)

elastic_net_train_mse = mean_squared_error(train_y, elastic_net_train_predictions)
elastic_net_test_mse = mean_squared_error(test_y, elastic_net_test_predictions)

print("\nElastic Net Regression Model:")
print(f"Train MSE: {elastic_net_train_mse}")
print(f"Test MSE: {elastic_net_test_mse}")
# Out:
# Linear Regression Model:
# Train MSE: 20.05705393954841
# Test MSE: 30.500176401058784
#
# Lasso Regression Model:
# Train MSE: 21.402662757963267
# Test MSE: 33.42796927220597
#
# Ridge Regression Model:
# Train MSE: 20.062533566680834
# Test MSE: 30.604966800825697
#
# Elastic Net Regression Model:
# Train MSE: 21.212443451596947
# Test MSE: 33.11984749910215
